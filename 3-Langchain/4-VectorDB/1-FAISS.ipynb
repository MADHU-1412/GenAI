# %% [markdown]
# ## FAISS
#
# Facebook AISimilary search (FAISS) - libfor efficient similarity search and clustering of dense vector. it contains algorithm that search in sets of vector of any size,up to ones that possible do not fit in RAM. It also contains supporting search for evaluation and parameter tuning.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
loader = TextLoader('speech.txt')
document = loader.load()
text_splitter = CharacterTextSplitter(chunk_size = 1000, chunk_overlap= 20)
docs = text_splitter.split_documents(document)

# %%
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Large Language Models are the core of this revolution. These models are trained on massive amounts of text from books, websites, research papers, conversations, and articles. They learn how words relate to each other, how sentences are structured, and how meaning flows in language. Instead of memorizing facts like a database, they learn patterns. When given a prompt, they predict the most likely next words based on everything they have learned. This allows them to answer questions, write essays, summarize documents, translate languages, generate computer code, and hold realistic conversations.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='The impact of these technologies is already visible across industries. In healthcare, AI helps doctors analyze medical scans, detect diseases earlier, predict patient risks, and personalize treatments. In education, AI tutors explain complex topics in simple language, adapt lessons to individual learning styles, and provide 24-hour support to students around the world. In business, AI automates customer service, generates marketing content, analyzes large datasets, and improves decision-making. In software development, AI writes code, tests applications, and fixes bugs faster than ever before.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Generative AI is also transforming scientific research. Scientists use AI to analyze massive amounts of data in fields like genetics, climate science, and physics. It accelerates drug discovery, helping researchers identify potential medicines in weeks instead of years. It helps model climate change scenarios, allowing governments to plan better environmental policies. AI is becoming a powerful partner in solving some of humanity’s biggest challenges.\n\nHowever, with such power come serious concerns. One major risk is misinformation. AI can generate fake news articles, false images, and realistic videos that are difficult to distinguish from real ones. This can spread confusion, manipulate public opinion, and damage trust in information. Another concern is bias. Since AI learns from human-created data, it can absorb and repeat existing social biases related to gender, race, or culture. Privacy is also a critical issue, as large datasets often include sensitive information.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Job displacement is another fear many people have. Automation may replace certain repetitive tasks in industries such as manufacturing, customer support, and data entry. But history shows that technological revolutions usually change jobs rather than eliminate them entirely. When computers were introduced, many feared the end of employment. Instead, new careers emerged in IT, software development, digital marketing, and data science. Similarly, AI will create new roles such as AI trainers, ethicists, prompt engineers, and human-AI collaboration specialists.\n\nThe future workforce will focus more on skills that machines struggle to replicate: creativity, emotional intelligence, critical thinking, leadership, and complex problem solving. AI will handle routine tasks, while humans will concentrate on innovation and strategy. In this way, AI becomes an assistant rather than a replacement.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Ethics will play a central role in shaping the future of AI. Developers and governments must ensure transparency in how AI systems make decisions. There must be accountability when AI causes harm. Fairness must be built into algorithms to avoid discrimination. Most importantly, humans must remain in control of critical decisions, especially in areas like healthcare, law enforcement, and national security.\n\nEducation systems must also evolve to prepare students for an AI-driven world. Learning should focus not only on memorizing information but on understanding concepts, thinking creatively, and using technology responsibly. AI literacy will become as essential as reading and writing. Students who understand how AI works will be better equipped to use it effectively and ethically.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='The relationship between humans and AI should not be seen as a competition. It should be viewed as a collaboration. Humans bring emotion, purpose, values, and imagination. AI brings speed, accuracy, and the ability to process enormous amounts of information. Together, they form a powerful combination capable of achieving things neither could accomplish alone.\n\nLooking ahead, we can imagine a world where personalized AI doctors monitor our health in real time, preventing diseases before symptoms appear. AI teachers could provide customized education to every child regardless of location or income. Smart cities could use AI to manage traffic, energy consumption, waste, and public safety efficiently. Scientific discoveries could happen at unprecedented speeds, unlocking solutions to climate change, hunger, and disease.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Rather than fearing this transformation, we should embrace it with wisdom. We should learn how to work alongside intelligent machines. We should use them to solve real-world problems, enhance creativity, and improve quality of life. The goal is not to build machines that replace humans, but to build tools that help humans reach their full potential.\n\nIn conclusion, Generative AI and Large Language Models are not just technological advancements; they are powerful forces shaping the future of society. They are changing how we learn, work, create, and communicate. They hold immense promise as well as serious responsibility. If guided correctly, they can lead us toward a world of greater knowledge, efficiency, creativity, and opportunity.\n\nThe future will not belong to AI alone.\nIt will belong to humans who understand AI, guide AI, and use AI wisely.\n\nAnd that future begins now.')]

# %%
embedding = OllamaEmbeddings(model = 'gemma:2b')
db = FAISS.from_documents(docs, embedding)

# %%
db

# %%
##quering
query = "What is Generative AI?"
doc = db.similarity_search(query)
doc
# Out:
# [Document(id='495f8d1c-2888-4dee-b2b2-8b5b41b5b0bc', metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#  Document(id='94322591-42c6-41dc-801a-cacaa7ebada7', metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#  Document(id='f83830bf-1972-42e5-970f-f7fafdf182f3', metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#  Document(id='3e2f9a7d-6f31-4f8b-affb-e122abbac575', metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.')]

# %%
doc[1].page_content
# Out:
# 'Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'

# %%
doc[0].page_content
# Out:
# 'Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'

# %% [markdown]
# ### As a Reteriver
# we can also convert the vector db into reterival class. this allow us to easily use it in other langchain methods, whcih largely uses in reterival

# %%
retrieval = db.as_retriever()
retrieval.invoke(query)
# Out:
# [Document(id='495f8d1c-2888-4dee-b2b2-8b5b41b5b0bc', metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#  Document(id='94322591-42c6-41dc-801a-cacaa7ebada7', metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#  Document(id='f83830bf-1972-42e5-970f-f7fafdf182f3', metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#  Document(id='3e2f9a7d-6f31-4f8b-affb-e122abbac575', metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.')]

# %%
docs[0].page_content
# Out:
# 'We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'

# %% [markdown]
# ### Similarity Search with Score
#
# #### there r some FAISS specific methods. one of them is similarity_search_with_score. which allows to u to return not only the score also the distance score of the query to them. the returned distance score is L2 distance. therfore lower score is better

# %%
docs_and_score = db.similarity_search_with_score(query)
docs_and_score
# Out:
# [(Document(id='495f8d1c-2888-4dee-b2b2-8b5b41b5b0bc', metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#   np.float32(2056.219)),
#  (Document(id='94322591-42c6-41dc-801a-cacaa7ebada7', metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#   np.float32(2148.482)),
#  (Document(id='f83830bf-1972-42e5-970f-f7fafdf182f3', metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#   np.float32(2228.2783)),
#  (Document(id='3e2f9a7d-6f31-4f8b-affb-e122abbac575', metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.'),
#   np.float32(2425.5908))]

# %%
#similarity search by vector

embedding_vector = embedding.embed_query(query)
embedding_vector
# Out:
# [-1.1420726776123047,
#  -1.4524930715560913,
#  -0.9919050335884094,
#  2.6927990913391113,
#  1.1165357828140259,
#  1.4074416160583496,
#  1.314515471458435,
#  -0.7074708938598633,
#  0.1734955757856369,
#  1.5800668001174927,
#  0.7172357439994812,
#  1.086014986038208,
#  -1.0724129676818848,
#  0.6055935025215149,
#  -0.47468826174736023,
#  0.12275147438049316,
#  7.638752460479736,
#  0.16079626977443695,
#  0.4377903640270233,
#  0.11443234235048294,
#  1.3078854084014893,
#  -0.36647722125053406,
#  -0.10603343695402145,
#  0.48358431458473206,
#  -2.4697964191436768,
#  -0.08499854803085327,
#  0.5191541910171509,
#  0.7549610733985901,
#  -0.2543017864227295,
#  -2.061140298843384,
#  -0.29515111446380615,
#  -0.38792622089385986,
#  -0.8896896839141846,
#  -0.7074491381645203,
#  0.05398281663656235,
#  1.1523545980453491,
#  -0.07655157893896103,
#  0.14772966504096985,
#  0.34549546241760254,
#  -1.6134473085403442,
#  0.30127280950546265,
#  0.3766326606273651,
#  0.9744135141372681,
#  0.1819518804550171,
#  -0.36336731910705566,
#  -1.2739553451538086,
#  0.7170514464378357,
#  -0.12223757803440094,
#  0.3159303665161133,
#  -0.5177637934684753,
#  -21.048107147216797,
#  -15.059822082519531,
#  -1.0802514553070068,
#  0.06021873280405998,
#  0.4276077449321747,
#  -0.27824756503105164,
#  -1.4448133707046509,
#  1.3545118570327759,
#  0.9463015198707581,
#  -0.46563470363616943,
#  0.42010796070098877,
#  -1.0411123037338257,
#  -1.400107741355896,
#  0.010843566618859768,
#  -2.6718432903289795,
#  0.14697951078414917,
#  1.0596623420715332,
#  0.9041273593902588,
#  2.3762753009796143,
#  0.6166296601295471,
#  -0.5678765773773193,
#  1.0569682121276855,
#  1.6937528848648071,
#  -0.5904733538627625,
#  0.13066181540489197,
#  0.5414954423904419,
#  1.9947651624679565,
#  -1.6910591125488281,
#  1.0224188566207886,
#  0.07353059202432632,
#  -0.5140510201454163,
#  1.667358160018921,
#  1.5884796380996704,
#  1.559622049331665,
#  -0.114342600107193,
#  0.4655929505825043,
#  0.22986501455307007,
#  -1.1611586809158325,
#  -0.9458492398262024,
#  -0.5559787750244141,
#  0.0834115669131279,
#  0.06499319523572922,
#  -0.7075424194335938,
#  -0.5422070622444153,
#  -1.630265235900879,
#  1.6785833835601807,
#  0.35166633129119873,
#  1.1961491107940674,
#  -1.1574482917785645,
#  0.44495561718940735,
#  -0.6227812170982361,
#  -1.6034870147705078,
#  0.04965595155954361,
#  0.8262364864349365,
#  0.40940535068511963,
#  -0.8304637670516968,
#  1.9893274307250977,
#  -1.4053267240524292,
#  -0.6345340013504028,
#  3.4230146408081055,
#  1.4333397150039673,
#  0.535977303981781,
#  0.30774345993995667,
#  0.38237640261650085,
#  -0.060796838253736496,
#  2.0662755966186523,
#  -0.5993713736534119,
#  1.6223548650741577,
#  2.415825366973877,
#  -1.1455575227737427,
#  -0.7239543199539185,
#  -1.143394112586975,
#  -3.7128379344940186,
#  1.2069581747055054,
#  0.30526724457740784,
#  -0.26791131496429443,
#  1.2470804452896118,
#  1.431510329246521,
#  -0.37178224325180054,
#  0.6665652394294739,
#  0.11481282860040665,
#  1.4122627973556519,
#  -1.2887370586395264,
#  -0.443053662776947,
#  0.108066126704216,
#  -1.1705788373947144,
#  -1.4619948863983154,
#  0.302074670791626,
#  1.9003679752349854,
#  -3.838327169418335,
#  -0.2929646372795105,
#  2.363112449645996,
#  0.022763608023524284,
#  -0.35399797558784485,
#  -0.9884428977966309,
#  0.060403261333703995,
#  -0.1203112006187439,
#  1.8429335355758667,
#  -1.3861987590789795,
#  0.3612978160381317,
#  0.8063533306121826,
#  -1.3394546508789062,
#  2.043863296508789,
#  0.44033753871917725,
#  -1.8016064167022705,
#  0.06645025312900543,
#  -0.6153647899627686,
#  0.3929145634174347,
#  0.4311806261539459,
#  0.36867591738700867,
#  -0.07522981613874435,
#  2.415329694747925,
#  2.105783462524414,
#  -0.6243761777877808,
#  1.3032950162887573,
#  0.7081226110458374,
#  0.4613820016384125,
#  1.782766580581665,
#  -0.5301620960235596,
#  1.0078705549240112,
#  0.8949955701828003,
#  1.0832022428512573,
#  0.43725597858428955,
#  -0.14676736295223236,
#  -0.4232815206050873,
#  -0.694301187992096,
#  1.4628021717071533,
#  -1.369322419166565,
#  0.6906470656394958,
#  0.9211486577987671,
#  0.4381612241268158,
#  -1.464363694190979,
#  0.09721997380256653,
#  1.327196717262268,
#  -0.25506818294525146,
#  1.0281791687011719,
#  -0.3955622911453247,
#  2.080162525177002,
#  11.487499237060547,
#  -0.19251063466072083,
#  0.9736557602882385,
#  16.39439582824707,
#  0.2817467749118805,
#  1.3492398262023926,
#  -0.30717891454696655,
#  -0.7627065777778625,
#  0.853968620300293,
#  0.7015649080276489,
#  2.4763295650482178,
#  -0.6012658476829529,
#  -1.0376213788986206,
#  0.6996135115623474,
#  2.416313648223877,
#  -4.346350193023682,
#  -5.359006881713867,
#  0.2881412208080292,
#  1.4605718851089478,
#  -1.8553435802459717,
#  -0.2225205898284912,
#  0.11259572952985764,
#  -1.0719389915466309,
#  -0.05104580894112587,
#  -1.0000449419021606,
#  0.612736701965332,
#  -0.03448253870010376,
#  -1.1026420593261719,
#  0.15312466025352478,
#  1.6013402938842773,
#  -0.30012375116348267,
#  1.053615927696228,
#  0.34668418765068054,
#  -1.2275481224060059,
#  -1.1672462224960327,
#  0.5608939528465271,
#  -0.7683795690536499,
#  1.7326819896697998,
#  -0.268959105014801,
#  -0.19846132397651672,
#  0.6024921536445618,
#  -1.4599888324737549,
#  0.7539259195327759,
#  1.3619054555892944,
#  1.981082558631897,
#  -0.3059957027435303,
#  1.9081538915634155,
#  -0.07249334454536438,
#  -0.9444525241851807,
#  0.66321861743927,
#  -0.18742017447948456,
#  1.4348808526992798,
#  0.7808792591094971,
#  0.7547199726104736,
#  0.4583204984664917,
#  -1.2547028064727783,
#  -0.8713388442993164,
#  4.202279090881348,
#  -3.764939308166504,
#  -0.0025817048735916615,
#  -0.020894819870591164,
#  -0.9457080960273743,
#  1.1797932386398315,
#  0.9718253016471863,
#  -0.38581183552742004,
#  -0.3128455579280853,
#  0.22242261469364166,
#  -0.3505372107028961,
#  0.48977550864219666,
#  0.8017902374267578,
#  -0.04288719221949577,
#  -1.028192400932312,
#  0.3334748148918152,
#  -1.8779370784759521,
#  -0.13772624731063843,
#  -1.350399374961853,
#  ...]

# %%
docs_score = db.similarity_search_by_vector(embedding_vector)

# %%
docs_score
# Out:
# [Document(id='495f8d1c-2888-4dee-b2b2-8b5b41b5b0bc', metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#  Document(id='94322591-42c6-41dc-801a-cacaa7ebada7', metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#  Document(id='f83830bf-1972-42e5-970f-f7fafdf182f3', metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#  Document(id='3e2f9a7d-6f31-4f8b-affb-e122abbac575', metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.')]

# %%
##Saving and loading 

db.save_local("faiss_index")

# %%
new_db = FAISS.load_local("faiss_index", embedding, allow_dangerous_deserialization = True)
docs = new_db.similarity_search(query)

# %%
docs
# Out:
# [Document(id='495f8d1c-2888-4dee-b2b2-8b5b41b5b0bc', metadata={'source': 'speech.txt'}, page_content='Artificial intelligence did not appear suddenly. It evolved slowly over decades. In the beginning, computers followed fixed rules written by programmers. If a condition was met, the machine performed a specific action. This was useful but limited. Later, machine learning allowed systems to learn from data instead of rules. Then deep learning introduced neural networks inspired by the human brain, enabling computers to recognize images, understand speech, and detect patterns. Now we have reached the generative era, where machines are not just analyzing existing information but creating new content. This is a fundamental shift in what technology can do.'),
#  Document(id='94322591-42c6-41dc-801a-cacaa7ebada7', metadata={'source': 'speech.txt'}, page_content='Generative AI goes beyond language. It includes systems that can create images, videos, music, designs, and even virtual worlds. An artist can describe a scene, and AI can generate a realistic painting. A musician can hum a tune, and AI can produce a full song. A business can describe a logo idea, and AI can design multiple versions instantly. Creativity, once limited by time and skill, is now amplified by technology.'),
#  Document(id='f83830bf-1972-42e5-970f-f7fafdf182f3', metadata={'source': 'speech.txt'}, page_content='We are living in one of the most important technological moments in human history. For the first time, machines are not only helping us calculate numbers or store information, but they are beginning to understand language, generate ideas, and create content that feels human-like. This transformation is being driven by Large Language Models and Generative Artificial Intelligence, commonly known as LLMs and GenAI. These technologies are reshaping education, healthcare, business, creativity, and the future of work itself.'),
#  Document(id='3e2f9a7d-6f31-4f8b-affb-e122abbac575', metadata={'source': 'speech.txt'}, page_content='But this future is not guaranteed to be positive by default. It depends on the choices we make today. If AI is developed responsibly, inclusively, and ethically, it can become one of the greatest tools for human progress. If misused or controlled by a few without oversight, it could deepen inequality and create serious risks.\n\nTherefore, our responsibility is clear. We must guide AI with human values. We must ensure it benefits all of society, not just a small group. We must remain curious, critical, and informed about how it works and how it is used.\n\nLarge Language Models and Generative AI represent a new chapter in the story of human innovation. Just as the printing press spread knowledge, electricity transformed industry, and the internet connected the world, AI is reshaping intelligence itself. It is expanding what is possible in ways we are only beginning to understand.')]
